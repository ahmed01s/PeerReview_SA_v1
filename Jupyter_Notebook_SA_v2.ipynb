# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio. #

# %% [markdown]
# **Sohail A.**
#
# Data Scientist

# %% [markdown]
# *I am interested in data science because it is the technological backbone of all current advancements and I love to contribute my part.*

# %% [markdown]
# ### The following code shows a simple aritmatic operation. ###

# %%
print(1+1)
# Out:
# 2

# %% [markdown]
# * First bullet item
# * Second bullet item
# * Third bullet item
# * Fourth bullet item
#
# 1. First item
# 2. Second item
# 3. Third item
#     1. Indented item
#     2. Indented item
# 4. Fourth item
#
#
# My favorite search engine is [Google] (https://www.google.com/).
